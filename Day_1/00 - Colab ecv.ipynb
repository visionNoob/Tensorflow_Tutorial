# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.14.0'

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.2.5'

# %%
pip list | grep keras
# Out:
# keras-vis                0.4.1

# %%
pip list | grep 2.2.5
# Out:
# Keras                    2.2.5

# %%
pip list | grep tensor
# Out:
# mesh-tensorflow          0.0.5
# tensor2tensor            1.11.0
# tensorboard              1.14.0
# tensorboardcolab         0.0.22
# tensorflow               1.14.0
# tensorflow-estimator     1.14.0
# tensorflow-hub           0.5.0
# tensorflow-metadata      0.14.0
# tensorflow-probability   0.7.0

# %%
# !uname -an
# Out:
# Linux 516220f0b678 4.14.137+ #1 SMP Thu Aug 8 02:47:02 PDT 2019 x86_64 x86_64 x86_64 GNU/Linux

# %%
cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %%
# !free -kh
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:            12G        773M         10G        844K        1.7G         11G
# Swap:            0B          0B          0B

# %%
# !df -kh
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          49G   26G   21G  56% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# tmpfs           6.4G  8.0K  6.4G   1% /var/colab
# /dev/sda1        55G   27G   29G  49% /etc/hosts
# shm             6.0G  8.0K  6.0G   1% /dev/shm
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
